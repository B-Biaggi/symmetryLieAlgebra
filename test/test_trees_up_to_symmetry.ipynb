# %%
import sys
sys.path.append("../lib")

load("../lib/staged_tree.sage")

# %%
stage_children = {1:3}

stages = [1]

max_depth = 2

trees_up_to_symmetry(max_depth, stage_children, stages)
# Out:
# [{(1,): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 1},
#   (1, 3): {'stage': 1}}]

# %%
stage_children = {1:3, 2:2} 

stages = [1,2] 
max_depth = 2

trees_up_to_symmetry(max_depth, stage_children, stages)
# Out:
# [{(1,): {'stage': 1}},
#  {(1,): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 2}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 1},
#   (1, 3): {'stage': 1}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 1},
#   (1, 3): {'stage': 2}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 2},
#   (1, 3): {'stage': 2}},
#  {(1,): {'stage': 1},
# ...

# %%
stage_children = {1:2, 2:2} 

stages = [1,2] 
max_depth = 2

trees_up_to_symmetry(max_depth, stage_children, stages, True)
# Out:
# [{(1,): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}, (1, 2): {'stage': 2}}]

# %%
stage_children = {1:3, 2:2} 

stages = [1,2] 
max_depth = 2

trees_up_to_symmetry(max_depth, stage_children, stages, True)
# Out:
# [{(1,): {'stage': 1}},
#  {(1,): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 1}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 1}, (1, 1): {'stage': 2}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}, (1, 2): {'stage': 1}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 1}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 2}, (1, 1): {'stage': 2}, (1, 2): {'stage': 2}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 1},
#   (1, 3): {'stage': 1}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 1},
#   (1, 3): {'stage': 2}},
#  {(1,): {'stage': 1},
#   (1, 1): {'stage': 1},
#   (1, 2): {'stage': 2},
#   (1, 3): {'stage': 2}},
#  {(1,): {'stage': 1},
# ...
